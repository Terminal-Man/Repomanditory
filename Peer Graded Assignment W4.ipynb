# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jason Antonelli**
# Intergalactic Mineral Farming

# %% [markdown]
# *I enjoy working with computers in my free-time, and would like to shift professionally in this direction.  Data Science seemed like the most practical educational path forward.  I should be able to learn what I am personally interested in while developing marketable skills along the way.*

# %% [markdown]
# ### The following, if produced accurately, should produce a simply mathematical equation. ###

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# 1. Item list no 1
# 2. ~~strikethrough~~
# 3. __[Google](https://www.google.com/)__
# 4. ![unnamed.jpg](attachment:1802e505-3705-4b70-b1d8-1b7231b9a38a.jpg)
